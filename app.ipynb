# %%
# app.py  ← Donor-Ready Version (World Bank / UNICEF / USAID standard)
import streamlit as st
import pandas as pd
import plotly.express as px

st.set_page_config(page_title="RCBDIA WASH-to-Service Dashboard", layout="wide")

# === DATA & SCORING (unchanged – 100% working) ===
@st.cache_data
def load_data():
    woreda = pd.read_csv("data/dim_woreda.csv")
    kebele = pd.read_csv("data/dim_kebele.csv")
    wuaf = pd.read_csv("data/dim_wuaf.csv")
    wp = pd.read_csv("data/dim_water_point.csv")
    kpi = pd.read_csv("data/fact_wuaf_kpi.csv")

    df = (kpi
          .merge(wuaf, on='wuaf_id', how='left')
          .merge(kebele, on='kebele_id', how='left')
          .merge(woreda, on='woreda_id', how='left')
          )

    def calc_score(r):
        s = (r['functionality_rate'] * 4 +
             r['tariff_collection_rate'] * 3 +
             min(r['meetings_held'], 2) * 0.5 +
             r['maintenance_done'] +
             (5 - min(r['user_complaints'], 5)) * 0.2 +
             r['water_quality_test'] +
             r['financial_audit'] +
             min(r['training_attended'], 3)/3 +
             r['wa_salary_paid'] +
             r['spare_parts_stock'] +
             min(r['emergency_fund']/2000, 1) +
             r['user_satisfaction_score'] * 0.2 +
             (r['wp_functional']/r['total_wp']) +
             (0.5 if r['has_business_plan'] else 0) +
             (0.5 if r['has_tariff'] else 0))
        return round(min(s, 15.0), 2)

    df['total_score'] = df.apply(calc_score, axis=1)
    df['performance_band'] = pd.cut(df['total_score'],
                                   bins=[0, 8.5, 11, 13.5, 15],
                                   labels=['Needs Support', 'Fair', 'Good', 'Excellent'],
                                   include_lowest=True)
    return df

df = load_data()

# === FILTER ===
st.sidebar.header("Filters")
selected_woreda = st.sidebar.selectbox("Woreda", ['All'] + sorted(df['woreda_name'].dropna().unique()))
if selected_woreda != 'All':
    df = df[df['woreda_name'] == selected_woreda]

# === HEADER ===
st.title("RCBDIA WASH-to-Service Dashboard")
st.markdown("**Wolaita Zone | 74 WUAFs | 148 Water Points | 179,280 beneficiaries**")

# === GLOSSARY & STANDARDS (Donor version – short & sharp) ===
with st.expander("Acronyms & Performance Standards", expanded=False):
    st.markdown("""
    **Acronyms**  
    • WASH – Water, Sanitation and Hygiene  
    • WUAF – Water Users Association Federation  
    • WP – Water Point  

    **RCBDIA & National Targets**  
    | Indicator                | Target      | Source                          |
    |--------------------------|-------------|---------------------------------|
    | Functionality Rate       | ≥ 95%       | OWNP-II / SDG 6                 |
    | Tariff Collection Rate   | ≥ 80%       | National Utility Guideline      |
    | User Satisfaction        | ≥ 4.2/5     | RCBDIA Community Scorecard      |
    | Emergency Fund           | ≥ 2,000 ETB | RCBDIA Sustainability Framework|
    | 15-Point Score           | ≥ 13.5      | Excellent = Utility-Ready       |
    """)

# === KPI CARDS ===
c1, c2, c3, c4 = st.columns(4)
c1.metric("Functionality Rate", f"{df['functionality_rate'].mean():.1%}", "Target ≥95%")
c2.metric("Tariff Collection", f"{df['tariff_collection_rate'].mean():.1%}", "Target ≥80%")
c3.metric("User Satisfaction", f"{df['user_satisfaction_score'].mean():.2f}/5", "Target ≥4.2")
c4.metric("15-Point Score", f"{df['total_score'].mean():.2f}/15", "Excellent ≥13.5")

# === SCORECARD ===
st.subheader("WUAF 15-Point Scorecard")
fig = px.scatter(df,
                 x='month', y='kebele_name',
                 size='total_score', color='performance_band',
                 hover_data=['wuaf_id', 'woreda_name', 'total_score'],
                 color_discrete_map={'Excellent':'#006400', 'Good':'#238823',
                                    'Fair':'#FFD700', 'Needs Support':'#DC143C'})
st.plotly_chart(fig, use_container_width=True)

# === RED FLAGS ===
st.subheader("Red Flags – Immediate Support Required")
alerts = df[(df['functionality_rate'] < 0.90) |
            (df['tariff_collection_rate'] < 0.70) |
            (df['emergency_fund'] < 1500)]

if not alerts.empty:
    st.error(f"{len(alerts)} WUAF(s) below critical threshold")
    st.dataframe(alerts[['wuaf_id','kebele_name','woreda_name','month',
                         'functionality_rate','tariff_collection_rate','emergency_fund']],
                 use_container_width=True)
else:
    st.success("All WUAFs performing above critical thresholds")

# === FOOTER ===
st.markdown("---")
st.caption("Developed by Aklilu Abera Dana | RCBDIA WASH Analytics | Wolaita Zone 2025")
# Out:
# 2025-11-17 19:31:45.611 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:45.810 No runtime found, using MemoryCacheStorageManager
# 2025-11-17 19:31:46.132 No runtime found, using MemoryCacheStorageManager
# 2025-11-17 19:31:46.510 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:46.511 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:46.533 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:46.620 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:47.891 Thread 'Thread-6': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:48.658 Thread 'Thread-6': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:48.766 Thread 'Thread-6': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.474 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.475 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.477 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.524 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.526 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.528 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.557 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.561 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.593 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.597 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.617 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.619 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.622 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.625 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.626 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.635 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.637 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.641 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.642 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.708 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.712 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.716 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.721 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.723 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.760 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.762 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.764 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.765 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.768 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.769 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.770 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.774 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.775 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.776 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.778 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.779 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.780 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.782 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.783 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.784 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.786 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.789 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:53.791 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:54.286 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2025-11-17 19:31:54.456 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:54.457 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:54.459 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:54.460 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:54.461 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:54.463 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:54.464 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:54.466 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:54.611 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:54.612 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:54.613 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:54.616 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2025-11-17 19:31:54.766 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:54.811 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:54.814 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:54.816 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:54.819 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:54.821 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:54.823 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:54.826 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 19:31:54.828 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
